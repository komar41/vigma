# %%
# %load_ext autoreload
# %autoreload 2

# %%
import emogis

# %%
file_dir = './data'
patient_id = '022318xz'
trial = 4

# %% [markdown]
# ### Format Conversion

# %% [markdown]
# `matToCSV()/trcToCSV()/c3dToCSV()`

# %%
df = emogis.matToCSV(file_dir, patient_id, trial)
df.head()
# Out:
#   frame#      time     RSlider                           Lslider              \
#                              X          Y          Z           X           Y
# 0      1  0.000000  984.617126  39.416691  79.357513  963.309998  652.304565
# 1      2  0.006667  984.435181  39.965942  79.637100  963.055542  652.503784
# 2      3  0.013333  984.437439  39.988850  79.663651  963.011780  652.505249
# 3      4  0.020000  984.760559  40.009857  79.557877  963.172852  652.505249
# 4      5  0.026667  984.766968  40.022362  79.580284  963.174927  652.523682
#
#                     Fix 2             ...    Rt.wrist Lt.shoulder              \
#            Z            X          Y  ...           Z           X           Y
# 0  76.069817  2487.009033 -22.823305  ...  853.884399 -972.569763  589.671509
# 1  75.885750  2487.018799 -22.792938  ...  853.964661 -966.161682  587.210022
# 2  75.886986  2487.027100 -22.846186  ...  853.968628 -965.762146  587.024292
# ...

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# `motionToJointAngle()`

# %%
df = emogis.motionToJointAngle(file_dir, patient_id, trial, save = True)
df.head()
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# Lt.heel                   Left heel
# Rt.heel                   Right heel
# Lt.toe                    Left toe
# Rt.toe                    Right toe
# Lt.knee                   Left knee
# Rt.knee                   Right knee
# Lt.ankle                  Left ankle
# Rt.Ankle                  Right ankle
# Lt.hip                    Left hip
# Rt.hip                    Right hip
# Lt.shoulder               Left shoulder
# Rt.shoulder               Right shoulder
#                    time #frame     Rfoot     Lfoot     Rshank     Lshank  \
# 0                   0.0      1 -3.112906  0.285014  82.885544  85.256547
# 1  0.006666666666666667      2 -2.939025  0.262664  82.788236  85.242994
# 2  0.013333333333333334      3 -2.923655  0.266824  82.786878  85.256767
# 3                  0.02      4 -2.449645  0.272163  83.033498  85.917125
# ...

# %% [markdown]
# ### Utility functions

# %% [markdown]
# `plot()`

# %%
# plot via file_dir, patient_id, trial
emogis.plot(data_type='jnt', 
                file_dir = file_dir, patient_id = patient_id, trial = trial) # default: steps = False, cycle=False

# %%
# plot via dataframe
emogis.plot(dataframe = df, data_type='jnt') # default: steps = False, cycle=False

# %% [markdown]
# ### Data Processing

# %% [markdown]
# `knn_impute()/mice_impute()/interpolate_impute()`

# %%
# data imputation via file_dir, patient_id, trial
df_imputed = emogis.knn_impute(file_dir = file_dir, patient_id = patient_id, trial = trial,
                                   data_type = 'jnt') # default: save = False, replace = False

# %%
# Or, data imputation via dataframe
df_imputed = emogis.knn_impute(dataframe = df, 
                                    data_type = 'jnt', save = False) # , replace = False

# %%
# if save is true, then either way (dataframe or file_dir) must give file_dir, patient_id, trial
df_imputed = emogis.knn_impute(dataframe = df, 
                                    data_type = 'jnt', 
                                        save = True, replace = True,
                                            file_dir = file_dir, patient_id = patient_id, trial = trial)

# %%
# Similar for: interpolate_impute, mice_impute, interpolate_impute

# %%
emogis.plot(dataframe = df_imputed, data_type='jnt')

# %% [markdown]
# `filter_data()`

# %%
df_filtered = emogis.filter_data(dataframe = df_imputed, 
                                    data_type = 'jnt')

# %%
emogis.plot(dataframe = df_filtered, data_type='jnt')

# %% [markdown]
# `plot()`: with step time

# %%
file_dir = "../backend/data/stroke_patients"
patient_id = '011918ds'
trial = 21

emogis.plot(data_type='grf',
               file_dir = file_dir, patient_id = patient_id, trial = trial, 
                    steps = True)

# %% [markdown]
# `mark_step_times()`

# %%
Left = [(4.87, 5.75), (6.02, 6.95)]
Right = [(5.5, 6.23), (6.70, 7.6)]
trialtype = 'Nat'

emogis.mark_step_times(file_dir, patient_id, trial, Left, Right, trialtype)

# %% [markdown]
# ### Feature Extraction
#
# `extract_stp()`

# %%
file_dir = "../backend/data/young"
patient_id = '010405sb'
trial = 7
step_params = emogis.extract_stp(file_dir, patient_id, trial)

print("Patient ID: %s, Trial: %d" % (patient_id, trial))
print("RstepLength: %f, LstepLength: %f, timeRswing: %f, timeLswing: %f, timeRGait: %f, timeLGait: %f, GaitSpeed: %f" 
      % (step_params[0], step_params[1], step_params[2], step_params[3], step_params[4], step_params[5], step_params[6]))
# Out:
# Patient ID: 010405sb, Trial: 7
# RstepLength: 0.626347, LstepLength: 0.693900, timeRswing: 0.675000, timeLswing: 0.702000, timeRGait: 1.063000, timeLGait: 1.080000, GaitSpeed: 1.464092

# %% [markdown]
# `get_stp_params()`

# %%
file_dir = "../backend/data/stroke_patients"
patient_id = '011918ds'
emogis.get_stp_params(file_dir, patient_id)
# Out:
#         sid  trial  RstepLength  LstepLength  timeRswing  timeLswing  \
# 0  011918ds     20     0.508326    -0.077962      0.6550      0.5300
# 1  011918ds     21     0.511617     0.384358      0.6883      0.9117
#
#    timeRgait  timeLgait  GaitSpeed
# 0       1.12      0.875   0.915283
# 1       1.07      1.275   0.789974

# %% [markdown]
# ### Data Processing
#
# `normalize_data()`

# %%
df = emogis.normalize_data(file_dir, patient_id, trial, data_type = 'jnt', cycle='L', save = False)
df.head()
# Out:
#        time     Rfoot      Lfoot     Rshank      Lshank     Rthigh  \
# 0  0.000000 -2.610000  16.018600  68.232400  104.758200  83.097300
# 1  1.010101 -3.651006  14.164447  66.860973  103.602417  82.613561
# 2  2.020202 -4.826984  12.282456  65.417873  102.417329  82.178857
# 3  3.030303 -6.156730  10.529600  63.898964  101.190336  81.810730
# 4  4.040404 -7.697180   9.068181  62.288331   99.838636  81.546817
#
#        Lthigh      trunk      hipx
# 0  114.401700  84.221200 -0.487200 NaN
# 1  114.078893  84.472364 -0.474403 NaN
# 2  113.728618  84.715625 -0.461575 NaN
# 3  113.372758  84.943706 -0.448709 NaN
# 4  113.047944  85.147259 -0.435812 NaN

# %% [markdown]
# `plot()`: normalized by cycle

# %%
emogis.plot(df = df, data_type='jnt', cycle=True)

# %% [markdown]
# ### Utility functions
#
# `load_data()`

# %%
emogis.load_data(file_dir, patient_id, group='healthy_controls')
