# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy.interpolate import interp1d

# %%
from format_convert import *
from feature_extraction import *

# %%
df = trcToCSV('data/input/041602jb1.trc')
df.head()
# Out:
#   frame#   time head vertex                         right ear             \
#                           X          Y           Z          X          Y
# 1    1.0  0.000   343.75946  245.51552  1728.31689  397.63239  148.26811
# 2    2.0  0.008   343.75946  245.51552  1728.31689  397.63239  148.26811
# 3    3.0  0.017   344.03885  245.52298  1728.36243  397.91818  148.22864
# 4    4.0  0.025   344.03885  245.52298  1728.36243  397.91818  148.22864
# 5    5.0  0.033   344.03885  245.52298  1728.36243  398.04483  148.54829
#
#                 left ear             ... left mth     slider            \
#             Z          X          Y  ...        Z          X         Y
# 1  1622.74231  395.71133  360.56482  ...  3.03345  965.91101 -21.14479
# 2  1622.74231  395.69720  360.99396  ...  3.03345  965.67474 -21.40953
# 3  1622.92114  396.36719  361.41528  ...  2.67758  965.91101 -21.14479
# 4  1622.92114  396.36719  361.41528  ...  2.67758  965.91101 -21.14479
# 5  1622.88379  396.36719  361.41528  ...  2.92389  965.91101 -21.14479
#
#                fixed 1                      fixed 2
#          Z           X         Y         Z        X        Y        Z
# 1  9.93127  1955.65491 -11.80660 -14.00936 -4.60406  1.00681  9.24365
# 2  9.74698  1956.15808 -11.79542 -13.62272 -4.28350  0.95118  8.98660
# 3  9.93127  1955.65491 -11.80660 -14.00936 -4.28350  0.95118  8.98660
# 4  9.93127  1955.65491 -11.80660 -14.00936 -4.28350  0.95118  8.98660
# 5  9.93127  1955.65491 -11.80660 -14.00936 -4.28350  0.95118  8.98660
#
# [5 rows x 86 columns]

# %%
df = matToCSV('data/input/022318xz0004.mat')
df.head()
# Out:
#   frame#      time     RSlider                           Lslider              \
#                              X          Y          Z           X           Y
# 0      1  0.000000  984.617126  39.416691  79.357513  963.309998  652.304565
# 1      2  0.006667  984.435181  39.965942  79.637100  963.055542  652.503784
# 2      3  0.013333  984.437439  39.988850  79.663651  963.011780  652.505249
# 3      4  0.020000  984.760559  40.009857  79.557877  963.172852  652.505249
# 4      5  0.026667  984.766968  40.022362  79.580284  963.174927  652.523682
#
#                     Fix 2             ...    Rt.wrist Lt.shoulder              \
#            Z            X          Y  ...           Z           X           Y
# 0  76.069817  2487.009033 -22.823305  ...  853.884399 -972.569763  589.671509
# 1  75.885750  2487.018799 -22.792938  ...  853.964661 -966.161682  587.210022
# 2  75.886986  2487.027100 -22.846186  ...  853.968628 -965.762146  587.024292
# 3  76.070160  2486.892334 -22.950426  ...  853.547302 -972.385376  589.745605
# 4  76.082802  2486.851074 -22.950968  ...  853.559692 -972.409485  589.556396
#
#                   Lt.elbow                            Lt.wrist              \
#              Z           X           Y           Z           X           Y
# 0  1211.283203 -966.540283  656.029358  984.180847 -888.710693  630.705261
# 1  1210.581177 -966.477234  655.984192  984.227356 -888.163879  630.567444
# 2  1210.597290 -966.384460  655.960571  984.280945 -888.320129  630.548401
# 3  1211.141113 -966.476440  655.919861  984.228333 -888.329590  630.350952
# 4  1211.227539 -966.500793  655.905151  984.285767 -888.174622  630.328247
#
#
#             Z
# 0  840.042542
# 1  840.249573
# 2  840.233582
# 3  840.277222
# 4  840.287048
#
# [5 rows x 92 columns]

# %%
df = c3dToCSV('data/input/022318xz0004.c3d')
df.head()
# Out:
#   frame#      time     RSlider                           Lslider              \
#                              X          Y          Z           X           Y
# 0      1  0.000000  984.617126  39.416691  79.357513  963.309998  652.304565
# 1      2  0.006667  984.435181  39.965942  79.637100  963.055542  652.503784
# 2      3  0.013333  984.437439  39.988850  79.663651  963.011780  652.505249
# 3      4  0.020000  984.760559  40.009857  79.557877  963.172852  652.505249
# 4      5  0.026667  984.766968  40.022362  79.580284  963.174927  652.523682
#
#                     Fix 2             ...    Rt.wrist Lt.shoulder              \
#            Z            X          Y  ...           Z           X           Y
# 0  76.069817  2487.009033 -22.823305  ...  853.884399 -972.569763  589.671509
# 1  75.885750  2487.018799 -22.792938  ...  853.964661 -966.161682  587.210022
# 2  75.886986  2487.027100 -22.846186  ...  853.968628 -965.762146  587.024292
# 3  76.070160  2486.892334 -22.950426  ...  853.547302 -972.385376  589.745605
# 4  76.082802  2486.851074 -22.950968  ...  853.559692 -972.409485  589.556396
#
#                   Lt.elbow                            Lt.wrist              \
#              Z           X           Y           Z           X           Y
# 0  1211.283203 -966.540283  656.029358  984.180847 -888.710693  630.705261
# 1  1210.581177 -966.477234  655.984192  984.227356 -888.163879  630.567444
# 2  1210.597290 -966.384460  655.960571  984.280945 -888.320129  630.548401
# 3  1211.141113 -966.476440  655.919861  984.228333 -888.329590  630.350952
# 4  1211.227539 -966.500793  655.905151  984.285767 -888.174622  630.328247
#
#
#             Z
# 0  840.042542
# 1  840.249573
# 2  840.233582
# 3  840.277222
# 4  840.287048
#
# [5 rows x 92 columns]

# %%
df = motionToJointAngle('data/output/041602jb1.csv')
try:
    display(df.head())
except:
    print('Error: No joint angle file generated.')
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# left heel                 Left heel
# right heel                Right heel
# left mth                  Left toe
# right mth                 Right toe
# left knee                 Left knee
# right knee                Right knee
# left ankle                Left ankle
# right ankle               Right ankle
# left g. trochanter        Left hip
# right g. trochanter       Right hip
# left shoulder             Left shoulder
# right shoulder            Right shoulder
#     time #frame       Rfoot       Lfoot     Rshank     Lshank     Rthigh  \
# 0    0.0    1.0  172.819544  169.884221  87.918957  83.761981  80.190517
# 1  0.008    2.0  172.819544  169.888241  87.960666  83.761981  80.168899
# 2  0.017    3.0  172.916897  169.773855  87.830066  83.651382  80.283721
# 3  0.025    4.0  172.916897  169.770052  87.838300  83.676647  80.283721
# 4  0.033    5.0  172.904923  169.883637  87.868419  83.676647  80.132323
#
#       Lthigh      Trunk
# 0  80.104491  96.656158
# 1  80.104491  96.687634
# 2  80.124428  96.691175
# 3  80.195537  96.691175
# 4  80.198407  96.670360

# %%
df = motionToJointAngle('data/output/022318xz0004.csv')
try:
    display(df.head())
except:
    print('Error: No joint angle file generated.')
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# Lt.heel                   Left heel
# Rt.heel                   Right heel
# Lt.toe                    Left toe
# Rt.toe                    Right toe
# Lt.knee                   Left knee
# Rt.knee                   Right knee
# Lt.ankle                  Left ankle
# Rt.Ankle                  Right ankle
# Lt.hip                    Left hip
# Rt.hip                    Right hip
# Lt.shoulder               Left shoulder
# Rt.shoulder               Right shoulder
#                    time #frame       Rfoot       Lfoot     Rshank     Lshank  \
# 0                   0.0      1  176.887094 -179.714986  82.885544  85.256547
# 1  0.006666666666666667      2  177.060975 -179.737336  82.788236  85.242994
# 2  0.013333333333333334      3  177.076345 -179.733176  82.786878  85.256767
# 3                  0.02      4  177.550355 -179.727837  83.033498  85.917125
# 4   0.02666666666666667      5  177.549562 -179.733118  83.046465  85.918616
#
#       Rthigh  Lthigh  Trunk
# 0  79.588158     NaN    NaN
# 1  79.711945     NaN    NaN
# 2  79.710037     NaN    NaN
# 3  79.666922     NaN    NaN
# 4  79.664594     NaN    NaN

# %%
df = motionToJointAngle('data/output/082119sm0013test.csv')
try:
    display(df.head())
except:
    print('Error: No joint angle file generated.')
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# Lt.heel                   Left heel
# Rt.heel                   Right heel
# Lt.toe                    Left toe
# Rt.toe                    Right toe
# Lt.knee                   Left knee
# Rt.knee                   Right knee
# Lt.ankle                  Left ankle
# Rt.Ankle                  Right ankle
# Lt.hip                    Left hip
# Rt.hip                    Right hip
# Lt.shoulder               Left shoulder
# Rt.shoulder               Right shoulder
#                    time #frame  Rfoot       Lfoot     Rshank     Lshank  \
# 0                   0.0      1    NaN  173.989465  75.153230  83.969849
# 1  0.006666666666666667      2    NaN  173.915760  75.220289  83.845869
# 2  0.013333333333333334      3    NaN  173.921596  75.220296  83.840298
# 3                  0.02      4    NaN  173.893991  75.290246  83.860518
# 4   0.02666666666666667      5    NaN  173.888201  75.269149  83.865256
#
#    Rthigh  Lthigh  Trunk
# 0     NaN     NaN    NaN
# 1     NaN     NaN    NaN
# 2     NaN     NaN    NaN
# 3     NaN     NaN    NaN
# 4     NaN     NaN    NaN

# %%
df = motionToJointAngle('data/output/082119sm0011_test.csv')
try:
    display(df.head())
except:
    print('Error: No joint angle file generated.')
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# Lt.heel                   Left heel
# Rt.heel                   Right heel
# Lt.toe                    Left toe
# Rt.toe                    Right toe
# Lt.knee                   Left knee
# Rt.knee                   Right knee
# Lt.ankle                  Left ankle
# Rt.Ankle                  Right ankle
# Lt.hip                    Left hip
# Rt.hip                    Right hip
# Lt.shoulder               Left shoulder
# Rt.shoulder               Right shoulder
#           time #frame  Rfoot       Lfoot     Rshank     Lshank  Rthigh  \
# 0            0      1    NaN  178.265331  75.403900  84.612900     NaN
# 1  0.006666667      2    NaN  178.214095  75.438705  84.680041     NaN
# 2  0.013333333      3    NaN  178.215211  75.447251  84.661668     NaN
# 3         0.02      4    NaN  178.181801  75.541356  84.706209     NaN
# 4  0.026666667      5    NaN  178.171475  75.546912  84.745666     NaN
#
#    Lthigh  Trunk
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
"""
# Finding missing values in all files in a directory

import os
import pandas as pd
os.getcwd()

dir = 'c:\\Users\\qshah\\iCloudDrive\\Spring 2023\\Research\\Gait\\Gait-Data-Processing\\pygait\\src\\tests\\data\\20 trials\\'

for file in os.listdir(dir):
    df = pd.read_csv(dir+'\\'+file)
    num_missing = df.isna().sum()
    print('_______________')
    print(file)
    print(num_missing) 
    
"""

# %% [markdown]
# ### Images for Teaser Image

# %%
# from PyGait.format_convert import *
# from PyGait.feature_extraction import *

# %%
# df_raw_trajectory = c3dToCSV('data/input/022318xz0004.c3d')
# df_grf = pd.read_csv('data/input/022318xz0004.csv')

# df_raw_trajectory = impute_missing_values(df_raw_trajectory)
# df_grf = impute_missing_values(df_grf)

# df_raw_trajectory = filter_noise(df_raw_trajectory, 'bandpass')
# df_grf = filter_noise(df_grf, 'bandpass')

# %%
# df_angle = motionToJointAngle(df)
# df_moment = computeJointMoment(df_angle, df_grf)
# df_spatiotemporal = extractSpatiotemporal(df_grf)

# %%
# mark_step_times(df_grf)

# %%
# df_angle = normalizeByGaitCycle(df_angle)

# %%
# createPatientGroup('Healthy Adults')

# patient_id = '022318'
# trial_id = '022318xz0004'

# upload_data('Healthy Adults', patient_id, trial_id)

# %%
# predictFallRisk(df_raw_trajectory, df_angle, df_grf)

# %% [markdown]
# ### Images for Teaser Image (End) **
