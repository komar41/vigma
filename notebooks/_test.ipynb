# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy.interpolate import interp1d

# %%
from format_convert import *
from feature_extraction import *
from preprocessing import *
from utils import *

# %%
# Format Conversion: format_convert.py
trcToCSV, matToCSV, c3dToCSV

# %%
file_location = '../data'
patient_id = '041602jb'
trial = 1

# %%
df = trcToCSV(file_location, patient_id, trial)
df.head()
# Out:
#   frame#   time head vertex                         right ear             \
#                           X          Y           Z          X          Y
# 1    1.0  0.000   343.75946  245.51552  1728.31689  397.63239  148.26811
# 2    2.0  0.008   343.75946  245.51552  1728.31689  397.63239  148.26811
# 3    3.0  0.017   344.03885  245.52298  1728.36243  397.91818  148.22864
# 4    4.0  0.025   344.03885  245.52298  1728.36243  397.91818  148.22864
# 5    5.0  0.033   344.03885  245.52298  1728.36243  398.04483  148.54829
#
#                 left ear             ... left mth     slider            \
#             Z          X          Y  ...        Z          X         Y
# 1  1622.74231  395.71133  360.56482  ...  3.03345  965.91101 -21.14479
# 2  1622.74231  395.69720  360.99396  ...  3.03345  965.67474 -21.40953
# 3  1622.92114  396.36719  361.41528  ...  2.67758  965.91101 -21.14479
# 4  1622.92114  396.36719  361.41528  ...  2.67758  965.91101 -21.14479
# ...

# %%
df = motionToJointAngle(file_location, patient_id, trial, save=True)
df.head()
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# left heel                 Left heel
# right heel                Right heel
# left mth                  Left toe
# right mth                 Right toe
# left knee                 Left knee
# right knee                Right knee
# left ankle                Left ankle
# right ankle               Right ankle
# left g. trochanter        Left hip
# right g. trochanter       Right hip
# left shoulder             Left shoulder
# right shoulder            Right shoulder
#     time #frame       Rfoot       Lfoot     Rshank     Lshank     Rthigh  \
# 0    0.0    1.0  172.819544  169.884221  87.918957  83.761981  80.190517
# 1  0.008    2.0  172.819544  169.888241  87.960666  83.761981  80.168899
# 2  0.017    3.0  172.916897  169.773855  87.830066  83.651382  80.283721
# 3  0.025    4.0  172.916897  169.770052  87.838300  83.676647  80.283721
# ...

# %%
patient_id = '082119sm'
trial = 11
df = motionToJointAngle(file_location, patient_id, trial, save=True)
# Out:
# Columns in CSV            Mapped Column
# ______________            _____________
# Lt.heel                   Left heel
# Rt.heel                   Right heel
# Lt.toe                    Left toe
# Rt.toe                    Right toe
# Lt.knee                   Left knee
# Rt.knee                   Right knee
# Lt.ankle                  Left ankle
# Rt.Ankle                  Right ankle
# Lt.hip                    Left hip
# Rt.hip                    Right hip
# Lt.shoulder               Left shoulder
# Rt.shoulder               Right shoulder

# %%
plot(data_type='jnt', steps = 'N', hip = 'N', df = df)

# %%
df_imputed = knn_impute(df, file_location = file_location, data_type = 'jnt', 
                        patient_id = patient_id, trial = trial, save = True, replace = False)
plot(data_type='jnt', steps = 'N', hip = 'N', df = df_imputed)

# %%
df_filtered = filter_df(df_imputed, file_location = file_location, data_type = 'jnt', 
                        patient_id = patient_id, trial = trial, save = True, replace = False)
plot(data_type='jnt', steps = 'N', hip = 'N', df = df_filtered)

# %%
patient_id = '081517ap'
trial = 8
plot(data_type='grf', file_location = file_location, 
     patient_id = patient_id, trial = trial, steps = 'Y')

# %%
L = [(2.285, 2.9783), (3.4, 4.0833)]
R = [(2.8083, 3.5617), (3.9283, 4.7083)]
trialtype = 'walk'

mark_step_times(L, R, file_location, patient_id, trial, trialtype)
# Out:
# Step time for trial already exists. Do you want to overwrite: ? (y/n)

# %%
get_stp_params(file_location, patient_id, save = True)
# Out:
#         sid  trial  RstepLength  LstepLength  timeRswing  timeLswing  \
# 0  081517ap      8     1.344197     1.377824      0.7534      0.6933
# 1  081517ap      9     1.500711     1.220891      0.7417      0.7500
#
#    timeRgait  timeLgait  GaitSpeed
# 0     1.1200      1.115   1.115111
# 1     1.0733      1.115   1.121815

# %%
df = normalize_data(file_location, patient_id, trial, data_type = 'jnt', cycle='L', save = True)

# %%
plot(data_type='grf', cycle=True, hip = 'N', df = df)

# %%
load_data(file_location, patient_id, group='healthy_controls')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
